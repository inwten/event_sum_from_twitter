# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm

nlp = spacy.blank("en") # load a new spacy model
db = DocBin() # create a DocBin object

# %%
import json
f = open('../1_500.json',encoding="utf8")
TRAIN_DATA = json.load(f)

# %%
print(json.dumps(TRAIN_DATA, indent=2))
# Out:
# {
#   "classes": [
#     "ACT",
#     "FAC",
#     "PERSON",
#     "GPE",
#     "LOC",
#     "TIME",
#     "DATE",
#     "ORG",
#     "NORP",
#     "EVENT",
#     "WORK_OF_ART",
#     "PRODUCT",
#     "GPE_WHO",
#     "LOC_WHO",
#     "FAC_WHO"
#   ],
#   "annotations": [
#     [
#       "#BREAKING: Nightmare in #Itaewon, Dozens of SouthKorean #Halloween revellers treated for cardiac arrest on pavement after stampede in Itaewon Around 160 people dead &amp; 100+ injured in a stampede during Halloween celebrations\r",
#       {
#         "entities": [
#           [
#             25,
#             32,
#             "FAC"
#           ],
#           [
#             44,
#             55,
#             "PERSON"
#           ],
#           [
#             57,
#             66,
#             "DATE"
#           ],
#           [
#             77,
#             84,
#             "ACT"
#           ],
#           [
#             134,
#             141,
#             "FAC"
#           ],
#           [
#             176,
#             183,
#             "ACT"
#           ],
#           [
#             205,
#             214,
#             "DATE"
#           ]
#         ]
#       }
#     ],
#     [
#       "storm system moving through the South will bring threats of severe thunderstorms and flooding rainfall through Saturday before weakening as it moves into the Ohio Valley around Halloween. The Storm Prediction Center issued a Tornado Watch\r",
#       {
#         "entities": [
#           [
#             13,
#             19,
#             "ACT"
#           ],
#           [
#             32,
#             37,
#             "LOC"
#           ],
#           [
#             43,
#             48,
#             "ACT"
#           ],
#           [
#             85,
#             93,
#             "ACT"
#           ],
#           [
#             111,
#             119,
#             "DATE"
#           ],
#           [
#             143,
#             148,
#             "ACT"
#           ],
#           [
#             158,
#             169,
#             "LOC"
#           ],
#           [
#             177,
#             187,
#             "DATE"
#           ],
#           [
#             192,
#             215,
#             "ORG"
#           ]
#         ]
#       }
#     ],
#     [
#       "\"DePape said that he was looking for Nancy Pelosi because he wanted to take her hostage and effectively interrogate her.\"\r",
#       {
#         "entities": [
#           [
#             1,
#             7,
#             "PERSON"
#           ],
#           [
#             8,
#             12,
#             "ACT"
#           ],
#           [
#             25,
#             32,
#             "ACT"
#           ],
#           [
#             37,
#             49,
#             "PERSON"
#           ],
#           [
#             61,
#             67,
#             "ACT"
#           ],
#           [
#             71,
#             75,
#             "ACT"
#           ],
#           [
#             104,
#             115,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "\"In a nightshirt, Pelosi then told the assailant he had to use the restroom\" What is this, the 1800's? What man wears a nite shirt anymore?\r",
#       {
#         "entities": [
#           [
#             18,
#             24,
#             "PERSON"
#           ],
#           [
#             30,
#             34,
#             "ACT"
#           ],
#           [
#             59,
#             62,
#             "ACT"
#           ],
#           [
#             95,
#             99,
#             "DATE"
#           ],
#           [
#             112,
#             117,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "\"LIVE: Presidential Summit on Gender-Based Violence and Femicide - SABC News - Breaking news, special reports, world, business, sport coverage of all South African current events. Africa's news leader.\"\r",
#       {
#         "entities": [
#           [
#             7,
#             19,
#             "PERSON"
#           ],
#           [
#             20,
#             26,
#             "ACT"
#           ],
#           [
#             150,
#             163,
#             "NORP"
#           ]
#         ]
#       }
#     ],
#     [
#       "\"More than half the fatalities were from a series of flash floods and landslides that destroyed villages on the Philippines' southern island of Mindanao over the weekend, the nation\u2019s disaster agency said.\" #ClimateEmergency\r",
#       {
#         "entities": [
#           [
#             86,
#             95,
#             "ACT"
#           ],
#           [
#             112,
#             123,
#             "GPE"
#           ],
#           [
#             144,
#             152,
#             "GPE"
#           ],
#           [
#             158,
#             169,
#             "DATE"
#           ],
#           [
#             200,
#             205,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "\"Safety Measures Ignored In Hurry To Open (Bridge)\": Engineer On Gujarat Tragedy - NDTV\r",
#       {
#         "entities": [
#           [
#             17,
#             24,
#             "ACT"
#           ],
#           [
#             37,
#             41,
#             "ACT"
#           ],
#           [
#             65,
#             72,
#             "GPE"
#           ],
#           [
#             83,
#             87,
#             "ORG"
#           ]
#         ]
#       }
#     ],
#     [
#       "\"Spoiler Alert\" HawaiiNewsNow Earthquake activities on Hawaii island in the week. It is likely that either a volcanic eruption or a large earthquake may occur in the near future. be cautious. #BREAKING\r",
#       {
#         "entities": [
#           [
#             55,
#             61,
#             "GPE"
#           ],
#           [
#             72,
#             81,
#             "DATE"
#           ],
#           [
#             153,
#             158,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Death toll from #Philippines flash floods rises to 67: official tally\r",
#       {
#         "entities": [
#           [
#             27,
#             38,
#             "GPE"
#           ],
#           [
#             52,
#             57,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Officials in Seoul said that at least 150 people were dead and 100 others were injured after a stampede in the South Korean capital's popular Itaewon district, where crowds had gathered to celebrate Halloween. newstakofficial\r",
#       {
#         "entities": [
#           [
#             23,
#             28,
#             "GPE"
#           ],
#           [
#             29,
#             33,
#             "ACT"
#           ],
#           [
#             89,
#             96,
#             "ACT"
#           ],
#           [
#             121,
#             133,
#             "NORP"
#           ],
#           [
#             152,
#             159,
#             "FAC"
#           ],
#           [
#             187,
#             195,
#             "ACT"
#           ],
#           [
#             199,
#             208,
#             "ACT"
#           ],
#           [
#             209,
#             219,
#             "DATE"
#           ],
#           [
#             220,
#             235,
#             "ORG"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Philippine floods death toll rises to 31: official (AFP)\r",
#       {
#         "entities": [
#           [
#             10,
#             20,
#             "NORP"
#           ],
#           [
#             39,
#             44,
#             "ACT"
#           ],
#           [
#             62,
#             65,
#             "ORG"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING The STC President offers condolences to the President of #India for the victims of the collapse of the pedestrian suspension bridge in India's western state of Gujarat #south24\r",
#       {
#         "entities": [
#           [
#             14,
#             17,
#             "ORG"
#           ],
#           [
#             28,
#             34,
#             "ACT"
#           ],
#           [
#             68,
#             73,
#             "GPE"
#           ],
#           [
#             97,
#             105,
#             "ACT"
#           ],
#           [
#             145,
#             150,
#             "GPE"
#           ],
#           [
#             170,
#             177,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Death toll from Philippines flash floods rises to 67: official tally #AFP\r",
#       {
#         "entities": [
#           [
#             26,
#             37,
#             "GPE"
#           ],
#           [
#             51,
#             56,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING On Friday, Nancy Pelosi was the target of an assassination attempt by a MAGA cultist. If she had been at home, she would be dead. The Speaker of the House would have been killed in an act of extremist political violence that severely injured her husband. Please RT\r",
#       {
#         "entities": [
#           [
#             13,
#             19,
#             "DATE"
#           ],
#           [
#             21,
#             33,
#             "PERSON"
#           ],
#           [
#             82,
#             86,
#             "ORG"
#           ],
#           [
#             181,
#             187,
#             "ACT"
#           ],
#           [
#             244,
#             251,
#             "ACT"
#           ],
#           [
#             272,
#             274,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING score for October is in - they beat #NYC once again, with monthly stats: 309 shot, and 64 dead. #crime\r",
#       {
#         "entities": [
#           [
#             20,
#             27,
#             "DATE"
#           ],
#           [
#             41,
#             45,
#             "ACT"
#           ],
#           [
#             47,
#             50,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Following Morbi tragedy, PM Modi cancels road show, page committee conference in Gujarat ... Afterall AntiNational Elements Are Successful in Stopping Modi's Rally in Election Bound Gujarat...\r",
#       {
#         "entities": [
#           [
#             38,
#             42,
#             "PERSON"
#           ],
#           [
#             43,
#             50,
#             "ACT"
#           ],
#           [
#             91,
#             98,
#             "GPE"
#           ],
#           [
#             152,
#             160,
#             "ACT"
#           ],
#           [
#             161,
#             165,
#             "PERSON"
#           ],
#           [
#             192,
#             199,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING A 5.9 magnitude earthquake hits Peru\r",
#       {
#         "entities": [
#           [
#             37,
#             41,
#             "ACT"
#           ],
#           [
#             42,
#             46,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING 'Massive attack' by Russia on Ukraine energy facilities: Ukraine presidency\r",
#       {
#         "entities": [
#           [
#             19,
#             25,
#             "ACT"
#           ],
#           [
#             30,
#             36,
#             "GPE"
#           ],
#           [
#             40,
#             47,
#             "GPE"
#           ],
#           [
#             67,
#             74,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING - Potential Tropical Cyclone 15 forms in Caribbean Sea - situated 265 miles SE of Kingston Tropical Storm Watches issued for Jamaica &amp; Grand Cayman\r",
#       {
#         "entities": [
#           [
#             51,
#             64,
#             "LOC"
#           ],
#           [
#             67,
#             75,
#             "ACT"
#           ],
#           [
#             92,
#             123,
#             "EVENT"
#           ],
#           [
#             124,
#             130,
#             "ACT"
#           ],
#           [
#             135,
#             142,
#             "GPE"
#           ],
#           [
#             149,
#             161,
#             "ORG"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING 100 Killed as 150 years old Gujarat Bridge Collapses Week After Renovation. Hope the Rescue and relief efforts save the missing and treat the injured. Praying for the families, rescue teams, relief work and the government! #gurajatbridge\r",
#       {
#         "entities": [
#           [
#             14,
#             20,
#             "ACT"
#           ],
#           [
#             24,
#             33,
#             "DATE"
#           ],
#           [
#             38,
#             45,
#             "GPE"
#           ],
#           [
#             53,
#             62,
#             "ACT"
#           ],
#           [
#             63,
#             67,
#             "DATE"
#           ],
#           [
#             86,
#             90,
#             "ACT"
#           ],
#           [
#             121,
#             125,
#             "ACT"
#           ],
#           [
#             142,
#             147,
#             "ACT"
#           ],
#           [
#             161,
#             168,
#             "ACT"
#           ],
#           [
#             187,
#             193,
#             "ACT"
#           ],
#           [
#             208,
#             212,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING : #MorbiBridgeCollapse | Prime Minister Narendra Modi to visit Morbi, Gujarat tomorrow, 1st November. #PMModi\r",
#       {
#         "entities": [
#           [
#             50,
#             63,
#             "PERSON"
#           ],
#           [
#             67,
#             72,
#             "ACT"
#           ],
#           [
#             73,
#             78,
#             "PERSON"
#           ],
#           [
#             80,
#             87,
#             "GPE"
#           ],
#           [
#             88,
#             96,
#             "DATE"
#           ],
#           [
#             98,
#             111,
#             "DATE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING : At least 60 people have died after a suspension bridge collapsed in India's Gujarat state, an official says. #news\r",
#       {
#         "entities": [
#           [
#             36,
#             40,
#             "ACT"
#           ],
#           [
#             67,
#             76,
#             "ACT"
#           ],
#           [
#             80,
#             85,
#             "GPE"
#           ],
#           [
#             88,
#             95,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING A Bridge has collapsed in India's Gujarat state sending hundreds plunging into a river, with at least 32 people confirmed dead.\r",
#       {
#         "entities": [
#           [
#             23,
#             32,
#             "ACT"
#           ],
#           [
#             36,
#             41,
#             "GPE"
#           ],
#           [
#             44,
#             51,
#             "GPE"
#           ],
#           [
#             58,
#             65,
#             "ACT"
#           ],
#           [
#             122,
#             131,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING An HPD SGT.says the rap group Migos, specifically Quavo &amp; Takeoff were at Billiards &amp; bowling alley on San Jacinto., when the shooting happened just before 3 a.m. A man police say was shot in the head &amp; killed.Investigators won\u2019t confirm if it was a group member KHOU\r",
#       {
#         "entities": [
#           [
#             60,
#             65,
#             "PERSON"
#           ],
#           [
#             121,
#             133,
#             "GPE"
#           ],
#           [
#             153,
#             161,
#             "ACT"
#           ],
#           [
#             174,
#             180,
#             "TIME"
#           ],
#           [
#             194,
#             197,
#             "ACT"
#           ],
#           [
#             202,
#             206,
#             "ACT"
#           ],
#           [
#             252,
#             259,
#             "ACT"
#           ],
#           [
#             285,
#             289,
#             "ORG"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING At least 100 people are feared trapped after a #cablebridge collapsed in #India's Gujarat province, on Sunday evening, local media NDTV reported.\r",
#       {
#         "entities": [
#           [
#             34,
#             40,
#             "ACT"
#           ],
#           [
#             41,
#             48,
#             "ACT"
#           ],
#           [
#             70,
#             79,
#             "ACT"
#           ],
#           [
#             84,
#             89,
#             "GPE"
#           ],
#           [
#             92,
#             99,
#             "GPE"
#           ],
#           [
#             113,
#             119,
#             "DATE"
#           ],
#           [
#             120,
#             127,
#             "TIME"
#           ],
#           [
#             141,
#             145,
#             "ORG"
#           ],
#           [
#             146,
#             154,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING At least 130 people were killed and 100 others were injured in a stampede in the popular Itaewon neighbourhood of the South Korean capital, where crowds had come to celebrate Halloween. #SeoulStampede\r",
#       {
#         "entities": [
#           [
#             35,
#             41,
#             "ACT"
#           ],
#           [
#             62,
#             69,
#             "ACT"
#           ],
#           [
#             99,
#             106,
#             "FAC"
#           ],
#           [
#             128,
#             140,
#             "NORP"
#           ],
#           [
#             167,
#             171,
#             "ACT"
#           ],
#           [
#             175,
#             184,
#             "ACT"
#           ],
#           [
#             185,
#             195,
#             "DATE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING At least 149 people were killed, 76 others injured in a deadly stampede in Seoul's Itaewon district, as huge crowds of partygoers stampeded at late-night Halloween celebrations, fire authorities said Sunday. For more:\r",
#       {
#         "entities": [
#           [
#             35,
#             41,
#             "ACT"
#           ],
#           [
#             53,
#             60,
#             "ACT"
#           ],
#           [
#             85,
#             90,
#             "GPE"
#           ],
#           [
#             93,
#             100,
#             "FAC"
#           ],
#           [
#             140,
#             149,
#             "ACT"
#           ],
#           [
#             153,
#             163,
#             "TIME"
#           ],
#           [
#             164,
#             173,
#             "DATE"
#           ],
#           [
#             205,
#             209,
#             "ACT"
#           ],
#           [
#             210,
#             217,
#             "DATE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING At least 30 people were killed and dozens critically injured when a suspension bridge in India's western Gujarat state collapsed on Sunday, Indian government said.\r",
#       {
#         "entities": [
#           [
#             34,
#             40,
#             "ACT"
#           ],
#           [
#             63,
#             70,
#             "ACT"
#           ],
#           [
#             99,
#             104,
#             "GPE"
#           ],
#           [
#             107,
#             122,
#             "LOC"
#           ],
#           [
#             129,
#             138,
#             "ACT"
#           ],
#           [
#             142,
#             148,
#             "DATE"
#           ],
#           [
#             150,
#             156,
#             "NORP"
#           ],
#           [
#             168,
#             172,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING At least 59 people have been killed and 150 others injured in a stampede in Seoul's Itaewon district amid Halloween festivities, the Yonhap news agency reports.\r",
#       {
#         "entities": [
#           [
#             39,
#             45,
#             "ACT"
#           ],
#           [
#             61,
#             68,
#             "ACT"
#           ],
#           [
#             86,
#             91,
#             "GPE"
#           ],
#           [
#             94,
#             101,
#             "FAC"
#           ],
#           [
#             116,
#             125,
#             "DATE"
#           ],
#           [
#             143,
#             161,
#             "ORG"
#           ],
#           [
#             162,
#             169,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING At least 60 dead in suspension bridge collapse in India\u2019s Gujarat state.",
#       {
#         "entities": [
#           [
#             22,
#             26,
#             "ACT"
#           ],
#           [
#             48,
#             56,
#             "ACT"
#           ],
#           [
#             68,
#             75,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING At least 60 dead in suspension bridge collapse in India\u2019s Gujarat state.",
#       {
#         "entities": [
#           [
#             22,
#             26,
#             "ACT"
#           ],
#           [
#             48,
#             56,
#             "ACT"
#           ],
#           [
#             68,
#             75,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Climate Activists Storm BlackRock HQ in NYC with pitchforks, dump coal on escalator as one man tries to stop and block them . Video by Ken Lopez / FreedomNTV\r",
#       {
#         "entities": [
#           [
#             34,
#             43,
#             "ORG"
#           ],
#           [
#             50,
#             53,
#             "GPE"
#           ],
#           [
#             71,
#             75,
#             "ACT"
#           ],
#           [
#             105,
#             110,
#             "ACT"
#           ],
#           [
#             114,
#             118,
#             "ACT"
#           ],
#           [
#             123,
#             128,
#             "ACT"
#           ],
#           [
#             145,
#             154,
#             "PERSON"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Death toll from Philippines flash floods rises to 67: official tally\r",
#       {
#         "entities": [
#           [
#             26,
#             37,
#             "GPE"
#           ],
#           [
#             51,
#             56,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Death toll from Philippines flash floods rises to 67: official tally #Philippines\r",
#       {
#         "entities": [
#           [
#             26,
#             37,
#             "GPE"
#           ],
#           [
#             51,
#             56,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING MOSCOW (UrduPoint News / Sputnik - 31st October, 2022) Russia has sent representatives ...\r",
#       {
#         "entities": [
#           [
#             10,
#             16,
#             "GPE"
#           ],
#           [
#             18,
#             32,
#             "ORG"
#           ],
#           [
#             35,
#             42,
#             "ORG"
#           ],
#           [
#             45,
#             63,
#             "DATE"
#           ],
#           [
#             65,
#             71,
#             "GPE_WHO"
#           ],
#           [
#             76,
#             80,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING News: About 150 people reported hurt in stampede in South Korea Emergency officials received at least 81 calls from people in the Itaewon area saying they were having difficulty breathing . #stampede\r",
#       {
#         "entities": [
#           [
#             33,
#             41,
#             "ACT"
#           ],
#           [
#             42,
#             46,
#             "ACT"
#           ],
#           [
#             62,
#             73,
#             "GPE"
#           ],
#           [
#             94,
#             102,
#             "ACT"
#           ],
#           [
#             140,
#             147,
#             "GPE"
#           ],
#           [
#             153,
#             159,
#             "ACT"
#           ],
#           [
#             170,
#             176,
#             "ACT"
#           ],
#           [
#             188,
#             197,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Philippine floods death toll rises to 31: official\r",
#       {
#         "entities": [
#           [
#             10,
#             20,
#             "NORP"
#           ],
#           [
#             39,
#             44,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Protest at the Morbi bridge collapse site ahead of Prime Minister Narendra Modi\u2019s arrival . This is Gujarat Opposition politician Reshma Patel . She says families of victims in this tragedy need answers about what\u2019s happened .\r",
#       {
#         "entities": [
#           [
#             21,
#             37,
#             "FAC"
#           ],
#           [
#             38,
#             46,
#             "ACT"
#           ],
#           [
#             76,
#             91,
#             "PERSON"
#           ],
#           [
#             110,
#             117,
#             "GPE"
#           ],
#           [
#             140,
#             152,
#             "PERSON"
#           ],
#           [
#             159,
#             163,
#             "ACT"
#           ],
#           [
#             200,
#             204,
#             "ACT"
#           ],
#           [
#             226,
#             234,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Rapper Takeoff, member of Migos, shot dead at 28: TMZ website\r",
#       {
#         "entities": [
#           [
#             36,
#             41,
#             "ORG"
#           ],
#           [
#             43,
#             47,
#             "ACT"
#           ],
#           [
#             60,
#             63,
#             "ORG"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Rapper Takeoff, of the group Migos, has been shot and killed . He was 28.\r",
#       {
#         "entities": [
#           [
#             39,
#             44,
#             "ORG"
#           ],
#           [
#             55,
#             59,
#             "ACT"
#           ],
#           [
#             64,
#             70,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Russia says hit Ukraine energy infrastructure with 'high-precision' strikes\r",
#       {
#         "entities": [
#           [
#             10,
#             16,
#             "GPE_WHO"
#           ],
#           [
#             17,
#             21,
#             "ACT"
#           ],
#           [
#             22,
#             25,
#             "ACT"
#           ],
#           [
#             26,
#             33,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Russian defence ministry says it wants 'commitments' from Ukraine not to use grain exports corridor for military purposes\r",
#       {
#         "entities": [
#           [
#             10,
#             34,
#             "ORG"
#           ],
#           [
#             35,
#             39,
#             "ACT"
#           ],
#           [
#             43,
#             48,
#             "ACT"
#           ],
#           [
#             49,
#             61,
#             "ACT"
#           ],
#           [
#             68,
#             75,
#             "GPE"
#           ],
#           [
#             83,
#             86,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING The Kremlin on Tuesday accused the United Kingdom of \"directing and coordinating\" explosions on the Nord Stream gas pipelines .\r",
#       {
#         "entities": [
#           [
#             25,
#             32,
#             "DATE"
#           ],
#           [
#             33,
#             40,
#             "ACT"
#           ],
#           [
#             41,
#             59,
#             "GPE"
#           ],
#           [
#             64,
#             73,
#             "ACT"
#           ],
#           [
#             78,
#             90,
#             "ACT"
#           ],
#           [
#             110,
#             121,
#             "FAC"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING The Storm has arrived in #Europe\r",
#       {
#         "entities": [
#           [
#             24,
#             31,
#             "ACT"
#           ],
#           [
#             36,
#             42,
#             "LOC"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING The head of Naftogaz of Ukraine Yuri Vitrenko wrote his resignation .\r",
#       {
#         "entities": [
#           [
#             22,
#             30,
#             "ORG"
#           ],
#           [
#             42,
#             55,
#             "PERSON"
#           ],
#           [
#             56,
#             61,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING UPDATE The death toll from the crowd crush in Seoul\u2019s Itaewon nightlife area has risen to 151, the city fire department said Sunday . Among the dead are 19 foreign nationals . Eighty-two others have been injured . -CNN\r",
#       {
#         "entities": [
#           [
#             56,
#             63,
#             "GPE"
#           ],
#           [
#             64,
#             71,
#             "GPE"
#           ],
#           [
#             91,
#             96,
#             "ACT"
#           ],
#           [
#             130,
#             134,
#             "GPE"
#           ],
#           [
#             135,
#             141,
#             "DATE"
#           ],
#           [
#             214,
#             221,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Ukraine says targeted by 'more than 50 missiles' from Russia\r",
#       {
#         "entities": [
#           [
#             10,
#             17,
#             "GPE_WHO"
#           ],
#           [
#             18,
#             22,
#             "ACT"
#           ],
#           [
#             23,
#             31,
#             "ACT"
#           ],
#           [
#             64,
#             70,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING Very sad scene . Over 100 people experience cardiac arrest for over crowding in Itaewon where thousands gathered for Halloween . #CardiacArrest\r",
#       {
#         "entities": [
#           [
#             43,
#             53,
#             "ACT"
#           ],
#           [
#             90,
#             97,
#             "GPE"
#           ],
#           [
#             114,
#             122,
#             "ACT"
#           ],
#           [
#             127,
#             136,
#             "DATE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING on #MorbiBridgeScam | Republic questions Gujarat CM Bhupendra Patel on the Morbi Bridge disaster: Why aren't specific people named in the FIR? Why was the bridge allowed to open despite no fitness clearance? Tune in #LIVE -\r",
#       {
#         "entities": [
#           [
#             14,
#             29,
#             "EVENT"
#           ],
#           [
#             41,
#             50,
#             "ACT"
#           ],
#           [
#             51,
#             58,
#             "GPE"
#           ],
#           [
#             62,
#             77,
#             "PERSON"
#           ],
#           [
#             81,
#             97,
#             "FAC"
#           ],
#           [
#             135,
#             140,
#             "ACT"
#           ],
#           [
#             172,
#             179,
#             "ACT"
#           ],
#           [
#             183,
#             187,
#             "ACT"
#           ],
#           [
#             218,
#             222,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING on #MorbiBridgeScam | Republic questions Gujarat CM Bhupendra Patel on the Morbi Bridge disaster; Tune in #LIVE -\r",
#       {
#         "entities": [
#           [
#             14,
#             29,
#             "EVENT"
#           ],
#           [
#             41,
#             50,
#             "ACT"
#           ],
#           [
#             51,
#             61,
#             "GPE"
#           ],
#           [
#             62,
#             77,
#             "PERSON"
#           ],
#           [
#             81,
#             97,
#             "FAC"
#           ],
#           [
#             108,
#             112,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | 'Government 's priority to rescue the stranded people . Death toll is 132,' says Gujarat Home Minister on Morbi bridge collapse . Tune in #LIVE:\r",
#       {
#         "entities": [
#           [
#             39,
#             45,
#             "ACT"
#           ],
#           [
#             50,
#             58,
#             "ACT"
#           ],
#           [
#             88,
#             92,
#             "ACT"
#           ],
#           [
#             93,
#             100,
#             "GPE"
#           ],
#           [
#             118,
#             130,
#             "FAC"
#           ],
#           [
#             142,
#             146,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | 132 deaths have been reported so far: Gujarat Home Minister Harsh Sanghavi on #MorbiBridgeCollapse\r",
#       {
#         "entities": [
#           [
#             33,
#             41,
#             "ACT"
#           ],
#           [
#             50,
#             57,
#             "GPE"
#           ],
#           [
#             72,
#             86,
#             "PERSON"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | 2 staff members of Oreva Group arrested by Gujarat Police on the basis of an FIR filed in the #GujaratBridgeCollapse:\r",
#       {
#         "entities": [
#           [
#             31,
#             42,
#             "ORG"
#           ],
#           [
#             43,
#             51,
#             "ACT"
#           ],
#           [
#             55,
#             62,
#             "GPE"
#           ],
#           [
#             93,
#             98,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | AIMIM chief Asaduddin Owaisi wades into UCC debate after Gujarat govt 's big announcement . Tune in -\r",
#       {
#         "entities": [
#           [
#             12,
#             17,
#             "ORG"
#           ],
#           [
#             24,
#             40,
#             "PERSON"
#           ],
#           [
#             41,
#             46,
#             "ACT"
#           ],
#           [
#             52,
#             55,
#             "ORG"
#           ],
#           [
#             69,
#             76,
#             "GPE"
#           ],
#           [
#             104,
#             108,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Big Move: Gujarat govt likely to formulate Uniform Civil Code (UCC) panel today, say sources . Tune in here for more -\r",
#       {
#         "entities": [
#           [
#             22,
#             29,
#             "GPE"
#           ],
#           [
#             45,
#             54,
#             "ACT"
#           ],
#           [
#             86,
#             91,
#             "DATE"
#           ],
#           [
#             93,
#             96,
#             "ACT"
#           ],
#           [
#             107,
#             111,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Big claim by Gujarat minister Harsh Sanghavi . The leader accuses AAP of 'sending money through hawala route' to Gujarat ahead of the polls . Tune in #LIVE:\r",
#       {
#         "entities": [
#           [
#             25,
#             32,
#             "GPE"
#           ],
#           [
#             42,
#             56,
#             "PERSON"
#           ],
#           [
#             70,
#             77,
#             "ACT"
#           ],
#           [
#             78,
#             81,
#             "ORG"
#           ],
#           [
#             85,
#             93,
#             "ACT"
#           ],
#           [
#             125,
#             132,
#             "GPE"
#           ],
#           [
#             154,
#             158,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Death count in Gujarat bridge collapse climbs to 130, 177 rescued so far\r",
#       {
#         "entities": [
#           [
#             27,
#             41,
#             "FAC"
#           ],
#           [
#             42,
#             50,
#             "ACT"
#           ],
#           [
#             51,
#             57,
#             "ACT"
#           ],
#           [
#             70,
#             77,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Delhi CM Arvind Kejriwal backs UCC but questions Gujarat govt 's intention; asks to 'bring all communities together' -\r",
#       {
#         "entities": [
#           [
#             12,
#             17,
#             "GPE"
#           ],
#           [
#             21,
#             36,
#             "PERSON"
#           ],
#           [
#             37,
#             42,
#             "ACT"
#           ],
#           [
#             43,
#             46,
#             "ORG"
#           ],
#           [
#             51,
#             60,
#             "ACT"
#           ],
#           [
#             61,
#             73,
#             "ORG"
#           ],
#           [
#             88,
#             92,
#             "ACT"
#           ],
#           [
#             96,
#             102,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Gujarat Chief Minister Bhupendra Patel reaches the #MorbiBridgeCollapse site; Tune in #LIVE here:\r",
#       {
#         "entities": [
#           [
#             12,
#             19,
#             "GPE"
#           ],
#           [
#             35,
#             50,
#             "PERSON"
#           ],
#           [
#             51,
#             58,
#             "ACT"
#           ],
#           [
#             90,
#             94,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Gujarat Home Minister Harsh Sanghavi tells Republic he will update on the latest casualty figures shortly; Tune in #LIVE here -\r",
#       {
#         "entities": [
#           [
#             12,
#             19,
#             "GPE"
#           ],
#           [
#             34,
#             48,
#             "PERSON"
#           ],
#           [
#             49,
#             54,
#             "ACT"
#           ],
#           [
#             72,
#             78,
#             "ACT"
#           ],
#           [
#             119,
#             123,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Gujarat Home Minister addresses media about the Morbi bridge collapse and shares details of the rescue operations . Tune in #LIVE:\r",
#       {
#         "entities": [
#           [
#             12,
#             19,
#             "GPE"
#           ],
#           [
#             34,
#             43,
#             "ACT"
#           ],
#           [
#             56,
#             72,
#             "FAC"
#           ],
#           [
#             73,
#             81,
#             "ACT"
#           ],
#           [
#             86,
#             92,
#             "ACT"
#           ],
#           [
#             128,
#             132,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Gujarat Home Minister assures 'rescue operations in full swing' as cable bridge collapse leaves several dead . Tune in -\r",
#       {
#         "entities": [
#           [
#             12,
#             19,
#             "GPE"
#           ],
#           [
#             34,
#             41,
#             "ACT"
#           ],
#           [
#             92,
#             100,
#             "ACT"
#           ],
#           [
#             101,
#             107,
#             "ACT"
#           ],
#           [
#             123,
#             127,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Gujarat Morbi Bridge Accident - More than 100 dead so far; 177 people have been rescued . Army, Air Force, Navy in rescue operation - State Information Department\r",
#       {
#         "entities": [
#           [
#             12,
#             19,
#             "GPE"
#           ],
#           [
#             20,
#             32,
#             "FAC"
#           ],
#           [
#             92,
#             99,
#             "ACT"
#           ],
#           [
#             146,
#             174,
#             "ORG"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | In a massive claim, Gujarat Minister Harsh Sanghavi accuses AAP of 'sending money through hawala route' ahead of assembly elections -\r",
#       {
#         "entities": [
#           [
#             32,
#             39,
#             "GPE"
#           ],
#           [
#             49,
#             63,
#             "PERSON"
#           ],
#           [
#             64,
#             71,
#             "ACT"
#           ],
#           [
#             72,
#             75,
#             "ORG"
#           ],
#           [
#             79,
#             87,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Morbi suspension bridge accident in Gujarat - death toll rises to 91 | #MorbiBridgeCollapse | #Gujarat\r",
#       {
#         "entities": [
#           [
#             12,
#             35,
#             "FAC"
#           ],
#           [
#             48,
#             55,
#             "GPE"
#           ],
#           [
#             58,
#             63,
#             "ACT"
#           ],
#           [
#             107,
#             114,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Morbi suspension bridge accident in Gujarat - death toll rises to 91 | #MorbiBridgeCollapse | #Gujarat\r",
#       {
#         "entities": [
#           [
#             12,
#             35,
#             "FAC"
#           ],
#           [
#             48,
#             55,
#             "GPE"
#           ],
#           [
#             69,
#             74,
#             "ACT"
#           ],
#           [
#             107,
#             114,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Most Halloween festivals, events &amp; parades cancelled in South Korea as the country mourns the deaths of 151 people in an overnight stampede in Seoul 's Itaewon last night: Local reports -\r",
#       {
#         "entities": [
#           [
#             17,
#             26,
#             "DATE"
#           ],
#           [
#             59,
#             68,
#             "ACT"
#           ],
#           [
#             72,
#             83,
#             "GPE"
#           ],
#           [
#             99,
#             105,
#             "ACT"
#           ],
#           [
#             137,
#             146,
#             "TIME"
#           ],
#           [
#             159,
#             164,
#             "GPE"
#           ],
#           [
#             168,
#             175,
#             "GPE"
#           ],
#           [
#             176,
#             186,
#             "TIME"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Multiple agencies, assisted by local residents, continue rescue operations in the Machchhu river in Gujarat as Republic reports from the ticket counter of Morbi Bridge . Tune in #LIVE here:\r",
#       {
#         "entities": [
#           [
#             31,
#             39,
#             "ACT"
#           ],
#           [
#             60,
#             68,
#             "ACT"
#           ],
#           [
#             69,
#             75,
#             "ACT"
#           ],
#           [
#             94,
#             102,
#             "GPE"
#           ],
#           [
#             112,
#             119,
#             "GPE"
#           ],
#           [
#             167,
#             179,
#             "FAC"
#           ],
#           [
#             182,
#             186,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | On Gujarat bridge collapse, Supreme Court to hear petition on November 14 seeking judicial probe\r",
#       {
#         "entities": [
#           [
#             15,
#             29,
#             "FAC"
#           ],
#           [
#             30,
#             38,
#             "ACT"
#           ],
#           [
#             40,
#             53,
#             "ORG"
#           ],
#           [
#             57,
#             61,
#             "ACT"
#           ],
#           [
#             74,
#             85,
#             "DATE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Outrage against human rights abuse in China . 50 nations seek release of detained Uyghurs . Tune in #LIVE:\r",
#       {
#         "entities": [
#           [
#             50,
#             55,
#             "GPE"
#           ],
#           [
#             69,
#             73,
#             "ACT"
#           ],
#           [
#             85,
#             93,
#             "ACT"
#           ],
#           [
#             94,
#             101,
#             "WORK_OF_ART"
#           ],
#           [
#             104,
#             108,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | PM Modi visits site of Gujarat bridge collapse in which 135 died on Sunday\r",
#       {
#         "entities": [
#           [
#             15,
#             19,
#             "PERSON"
#           ],
#           [
#             20,
#             26,
#             "ACT"
#           ],
#           [
#             35,
#             49,
#             "FAC"
#           ],
#           [
#             50,
#             58,
#             "ACT"
#           ],
#           [
#             72,
#             76,
#             "ACT"
#           ],
#           [
#             80,
#             86,
#             "DATE"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | PM Narendra Modi cancels his events in Gujarat today after 132 die in bridge tragedy\r",
#       {
#         "entities": [
#           [
#             15,
#             28,
#             "PERSON"
#           ],
#           [
#             29,
#             36,
#             "ACT"
#           ],
#           [
#             51,
#             58,
#             "GPE"
#           ],
#           [
#             59,
#             64,
#             "DATE"
#           ],
#           [
#             75,
#             78,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | PM Narendra Modi cancels his events in Gujarat today after 132 die in bridge tragedy NDTV 's Sanket Upadhyay reports\r",
#       {
#         "entities": [
#           [
#             15,
#             28,
#             "PERSON"
#           ],
#           [
#             29,
#             36,
#             "ACT"
#           ],
#           [
#             51,
#             58,
#             "GPE"
#           ],
#           [
#             59,
#             64,
#             "DATE"
#           ],
#           [
#             75,
#             78,
#             "ACT"
#           ],
#           [
#             97,
#             101,
#             "ORG"
#           ],
#           [
#             105,
#             120,
#             "PERSON"
#           ],
#           [
#             121,
#             128,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING | Republic impact: Gujarat police places focus on Oreva, seeks details from registrar of companies . Tune in -\r",
#       {
#         "entities": [
#           [
#             29,
#             36,
#             "GPE"
#           ],
#           [
#             51,
#             56,
#             "ACT"
#           ],
#           [
#             67,
#             72,
#             "GPE"
#           ],
#           [
#             111,
#             115,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING 1/ San Francisco District Attorney BrookeJenkinsSF releases new details about attack on Speaker Nancy Pelosi 's husband, Paul Pelosi . She says David Depape broke a glass door to get into the Pelosi 's SF home, went to 2nd floor to find Paul Pelosi sleeping in bed .\r",
#       {
#         "entities": [
#           [
#             13,
#             26,
#             "GPE"
#           ],
#           [
#             45,
#             60,
#             "PERSON"
#           ],
#           [
#             61,
#             69,
#             "ACT"
#           ],
#           [
#             106,
#             118,
#             "PERSON"
#           ],
#           [
#             131,
#             142,
#             "PERSON"
#           ],
#           [
#             149,
#             153,
#             "ACT"
#           ],
#           [
#             154,
#             166,
#             "PERSON"
#           ],
#           [
#             167,
#             172,
#             "ACT"
#           ],
#           [
#             189,
#             192,
#             "ACT"
#           ],
#           [
#             202,
#             208,
#             "PERSON"
#           ],
#           [
#             212,
#             214,
#             "GPE"
#           ],
#           [
#             221,
#             225,
#             "ACT"
#           ],
#           [
#             242,
#             246,
#             "ACT"
#           ],
#           [
#             247,
#             258,
#             "PERSON"
#           ],
#           [
#             259,
#             267,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "#BREAKING: is in trouble said thousands of people have breathing problems after the #stampede at Itaewon in #Seoul,\r",
#       {
#         "entities": [
#           [
#             25,
#             29,
#             "ACT"
#           ],
#           [
#             55,
#             64,
#             "ACT"
#           ],
#           [
#             97,
#             104,
#             "GPE"
#           ],
#           [
#             109,
#             114,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
# ...
#         "entities": [
#           [
#             6,
#             8,
#             "ACT"
#           ],
#           [
#             102,
#             123,
#             "GPE"
#           ],
#           [
#             134,
#             141,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "There is a storm approaching Windsor between 01/11/2022 12:35 and 01/11/2022 12:40 Storm Alert Windsor 2022 - 11 - 01T12:35:00.000Z 00:05:00 51.47852 \u00b0 N 00.63869 \u00b0 W\r",
#       {
#         "entities": [
#           [
#             6,
#             8,
#             "ACT"
#           ],
#           [
#             45,
#             55,
#             "DATE"
#           ],
#           [
#             56,
#             61,
#             "TIME"
#           ],
#           [
#             66,
#             76,
#             "DATE"
#           ],
#           [
#             77,
#             82,
#             "TIME"
#           ]
#         ]
#       }
#     ],
#     [
#       "There is so much happenings in 2021 - 2022 CoVid Typhoon Stampede I really want ppl to be more careful , You are all precious human beings ... My sincere Condolences to Itaewon , and Stay Careful from floods and typhoons ...\r",
#       {
#         "entities": [
#           [
#             6,
#             8,
#             "ACT"
#           ],
#           [
#             31,
#             42,
#             "DATE"
#           ],
#           [
#             75,
#             79,
#             "ACT"
#           ],
#           [
#             169,
#             176,
#             "GPE"
#           ],
#           [
#             183,
#             187,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "There was a 2.5 magnitude earthquake 26 km W of Old Harbor , Alaska\r",
#       {
#         "entities": [
#           [
#             6,
#             9,
#             "ACT"
#           ],
#           [
#             61,
#             67,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "There was a 2.5 magnitude earthquake 50 km ESE of Port Alsworth , Alaska\r",
#       {
#         "entities": [
#           [
#             6,
#             9,
#             "ACT"
#           ],
#           [
#             50,
#             63,
#             "GPE"
#           ],
#           [
#             66,
#             72,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "There were at least 100 people on the bridge when it collapsed . Around 40 people were rescued and 60 were still missing . Some five to ten were hanging on the bridge who are being rescued : Gujarat DGP # AshishBhatia\r",
#       {
#         "entities": [
#           [
#             6,
#             10,
#             "ACT"
#           ],
#           [
#             53,
#             62,
#             "ACT"
#           ],
#           [
#             87,
#             94,
#             "ACT"
#           ],
#           [
#             113,
#             120,
#             "ACT"
#           ],
#           [
#             145,
#             152,
#             "ACT"
#           ],
#           [
#             181,
#             188,
#             "ACT"
#           ],
#           [
#             191,
#             198,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "This is what really happened as opposed to the bull shit posed by the MAGA republicans . These are legal filings not QANON conspiracies spouted by assholes .   : DOJ brings FEDERAL CHARGES against Pelosi Attacker which INCLU ... via YouTube\r",
#       {
#         "entities": [
#           [
#             20,
#             28,
#             "ACT"
#           ],
#           [
#             57,
#             62,
#             "ACT"
#           ],
#           [
#             70,
#             74,
#             "ORG"
#           ],
#           [
#             75,
#             86,
#             "NORP"
#           ],
#           [
#             136,
#             143,
#             "ACT"
#           ],
#           [
#             162,
#             165,
#             "ORG"
#           ],
#           [
#             166,
#             172,
#             "ACT"
#           ],
#           [
#             197,
#             203,
#             "PERSON"
#           ]
#         ]
#       }
#     ],
#     [
#       "This is n't about left or right , it 's about right and wrong .   : DOJ brings FEDERAL CHARGES against Pelosi Attacker which INCLU ... via YouTube\r",
#       {
#         "entities": [
#           [
#             68,
#             71,
#             "ORG"
#           ],
#           [
#             72,
#             78,
#             "ACT"
#           ],
#           [
#             103,
#             109,
#             "PERSON"
#           ]
#         ]
#       }
#     ],
#     [
#       "Tiny earthquake feltin Waikoloa just now ? ? 11.1.22 1:18am\r",
#       {
#         "entities": [
#           [
#             16,
#             22,
#             "ACT"
#           ],
#           [
#             23,
#             31,
#             "PERSON"
#           ],
#           [
#             45,
#             52,
#             "DATE"
#           ],
#           [
#             53,
#             59,
#             "TIME"
#           ]
#         ]
#       }
#     ],
#     [
#       "To all foreign visitors who are thinking of going to Japan now . Tokyo is on the border where four plates overlap . Eurasia , North America , Philippines , Pacific . There is always the risk of a major earthquake at any time .\r",
#       {
#         "entities": [
#           [
#             32,
#             40,
#             "ACT"
#           ],
#           [
#             44,
#             49,
#             "ACT"
#           ],
#           [
#             53,
#             58,
#             "GPE"
#           ],
#           [
#             65,
#             70,
#             "GPE_WHO"
#           ],
#           [
#             126,
#             139,
#             "GPE"
#           ],
#           [
#             142,
#             153,
#             "GPE"
#           ],
#           [
#             156,
#             163,
#             "GPE"
#           ],
#           [
#             172,
#             174,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "To those people who are affected by an earthquake in Abra and onslaught of Tropical Storm Paeng , my donation aid is coming do n't worry . I will pray for your safety and together , we heal as one nation . Thank you and god bless .\r",
#       {
#         "entities": [
#           [
#             24,
#             32,
#             "ACT"
#           ],
#           [
#             53,
#             57,
#             "GPE"
#           ],
#           [
#             117,
#             123,
#             "ACT"
#           ],
#           [
#             131,
#             136,
#             "ACT"
#           ],
#           [
#             146,
#             150,
#             "ACT"
#           ],
#           [
#             185,
#             189,
#             "ACT"
#           ],
#           [
#             206,
#             211,
#             "ACT"
#           ],
#           [
#             224,
#             229,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "Today is the # GreatShakeOut - # 29Palms encourages you to learn how to protect yourself by following the seven steps to earthquake safety here :\r",
#       {
#         "entities": [
#           [
#             0,
#             5,
#             "DATE"
#           ],
#           [
#             41,
#             51,
#             "ACT"
#           ],
#           [
#             59,
#             64,
#             "ACT"
#           ],
#           [
#             72,
#             79,
#             "ACT"
#           ],
#           [
#             92,
#             101,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "Today 's attacks on Ukrainian infrastructure are partly a RESPONSE to the attack on Black Sea Fleet in Sevastopol , South Russia but we have capability to do MORE - Putin . #  \r",
#       {
#         "entities": [
#           [
#             0,
#             5,
#             "DATE"
#           ],
#           [
#             20,
#             29,
#             "NORP"
#           ],
#           [
#             84,
#             99,
#             "GPE"
#           ],
#           [
#             103,
#             113,
#             "GPE"
#           ],
#           [
#             116,
#             128,
#             "GPE"
#           ],
#           [
#             136,
#             140,
#             "ACT"
#           ],
#           [
#             165,
#             170,
#             "PERSON"
#           ]
#         ]
#       }
#     ],
#     [
#       "Today , Friendship Federation donates \u20b1 119 to GMA Kapuso Foundation Inc. for the victims of earthquake in Abra and areas affected by Tropical Storm Paeng . # LongLiveTheFriendshipSpirit\r",
#       {
#         "entities": [
#           [
#             0,
#             5,
#             "DATE"
#           ],
#           [
#             8,
#             29,
#             "ORG"
#           ],
#           [
#             30,
#             37,
#             "ACT"
#           ],
#           [
#             47,
#             73,
#             "ORG"
#           ],
#           [
#             107,
#             111,
#             "GPE"
#           ],
#           [
#             122,
#             130,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "Top # IndieGames Out This Week # 44 ! DarknotGame / Darknot Team Space Tail : Every Journey Leads Home / GamesLongterm A Walk With YiaYia / TrentGarlipp Lonesome Village / OgrePixel The First Men / GatheringTreeGS Against The Storm / EremiteGames # LetsDIGin\r",
#       {
#         "entities": [
#           [
#             92,
#             97,
#             "ACT"
#           ],
#           [
#             172,
#             181,
#             "PERSON"
#           ],
#           [
#             234,
#             246,
#             "PERSON"
#           ]
#         ]
#       }
#     ],
#     [
#       "Top story : MediaWarriorY : ' #   : # SouthKorea 's fire department said 81 people have breathing problems after the # stampede at Itaewon in # Seoul , South Korea Saturday night when over 100 thousand revellers crammed i \u2026 see more\r",
#       {
#         "entities": [
#           [
#             38,
#             48,
#             "ORG"
#           ],
#           [
#             68,
#             72,
#             "ACT"
#           ],
#           [
#             88,
#             97,
#             "ACT"
#           ],
#           [
#             131,
#             138,
#             "GPE"
#           ],
#           [
#             144,
#             149,
#             "GPE"
#           ],
#           [
#             152,
#             163,
#             "GPE"
#           ],
#           [
#             164,
#             172,
#             "DATE"
#           ],
#           [
#             173,
#             178,
#             "TIME"
#           ],
#           [
#             212,
#             219,
#             "ACT"
#           ],
#           [
#             224,
#             227,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "Top story : PrateekPratap5 : '   News : About 50 people reported hurt in stampede in South Korea Emergency officials received at least 81 calls from people in the Itaewon area saying they were having difficulty bre \u2026 see more\r",
#       {
#         "entities": [
#           [
#             56,
#             64,
#             "ACT"
#           ],
#           [
#             85,
#             96,
#             "GPE"
#           ],
#           [
#             117,
#             125,
#             "ACT"
#           ],
#           [
#             163,
#             170,
#             "GPE"
#           ],
#           [
#             176,
#             182,
#             "ACT"
#           ],
#           [
#             193,
#             199,
#             "ACT"
#           ],
#           [
#             217,
#             220,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "Tropical Storm # Lisa Advisory 7A : Lisa Poised to Strengthen Today . Air Force Reserve Hurricane Hunter Aircraft Investigating the Storm .\r",
#       {
#         "entities": [
#           [
#             36,
#             40,
#             "PERSON"
#           ],
#           [
#             41,
#             47,
#             "ACT"
#           ],
#           [
#             62,
#             67,
#             "DATE"
#           ],
#           [
#             114,
#             127,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "Tropical Storm # Lisa is getting a little better organized on satellite , but so far it 's not translating to a significant drop in pressure or increase in wind speed . We 'll see how things evolve throughout the day - the outflow looks healthy , but there 's still dry air to the west .\r",
#       {
#         "entities": [
#           [
#             25,
#             32,
#             "ACT"
#           ],
#           [
#             95,
#             106,
#             "ACT"
#           ],
#           [
#             176,
#             179,
#             "ACT"
#           ],
#           [
#             191,
#             197,
#             "ACT"
#           ],
#           [
#             209,
#             216,
#             "DATE"
#           ],
#           [
#             231,
#             236,
#             "ACT"
#           ],
#           [
#             257,
#             259,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "Tropical Storm # Lisa which was named yesterday continues to trek toward Belize and # 96L has a high chance of development , next name is # Martin which would make it 's debut # HurricaneSeason\r",
#       {
#         "entities": [
#           [
#             32,
#             37,
#             "ACT"
#           ],
#           [
#             38,
#             47,
#             "DATE"
#           ],
#           [
#             61,
#             65,
#             "ACT"
#           ],
#           [
#             90,
#             93,
#             "ACT"
#           ],
#           [
#             159,
#             163,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "Tropical Storm Lisa Is Expected to Become a Hurricane in the Caribbean\r",
#       {
#         "entities": [
#           [
#             23,
#             31,
#             "ACT"
#           ],
#           [
#             35,
#             41,
#             "ACT"
#           ]
#         ]
#       }
#     ],
#     [
#       "Tropical Storm Lisa is expected to strengthen on Tuesday as it passes the Cayman Islands before reaching hurricane status on Wednesday , forecasters said . A hurricane watch is in effect for the Bay Islands , off the coast of Honduras , and parts of Belize .\r",
#       {
#         "entities": [
#           [
#             23,
#             31,
#             "ACT"
#           ],
#           [
#             49,
#             56,
#             "DATE"
#           ],
#           [
#             63,
#             69,
#             "ACT"
#           ],
#           [
#             96,
#             104,
#             "ACT"
#           ],
#           [
#             125,
#             134,
#             "DATE"
#           ],
#           [
#             149,
#             153,
#             "ACT"
#           ],
#           [
#             226,
#             234,
#             "GPE"
#           ],
#           [
#             250,
#             256,
#             "GPE"
#           ]
#         ]
#       }
#     ],
#     [
#       "Tropical Storm Lisa to strengthen into a hurricane while a second system could become Tropical Storm Martin this week . # islandernews\r",
#       {
#         "entities": [
#           [
#             23,
#             33,
#             "ACT"
#           ],
#           [
#             79,
#             85,
#             "ACT"
#           ],
#           [
#             108,
#             117,
#             "DATE"
#           ]
#         ]
#       }
#     ],
#     [
#       "Tropical Storm Lisa will track west and strengthen to a hurricane before making landfall along the coast of Belize by late Wednesday .\r",
#       {
#         "entities": [
#           [
#             25,
#             30,
#             "ACT"
#           ],
#           [
#             40,
#             50,
#             "ACT"
#           ],
#           [
#             73,
#             79,
#             "ACT"
#           ],
#           [
#             108,
#             114,
#             "GPE"
#           ],
#           [
#             118,
#             132,
#             "DATE"
#           ]
#         ]
#       }
#     ],
#     [
#       "Tropical Storm Nalgae has killed at least 98 people in the Philippines and injured dozens more , after unleashing floods and landslides",
#       {
#         "entities": [
#           [
#             26,
#             32,
#             "ACT"
#           ],
#           [
#             59,
#             70,
#             "GPE"
#           ],
#           [
#             103,
#             113,
#             "ACT"
#           ]
#         ]
#       }
#     ]
#   ]
# }

# %%
i=0
for text, annot in tqdm(TRAIN_DATA['annotations']): 
    i+=1
    # print("i =",i)
    j=0
    doc = nlp.make_doc(text) 
    ents = []
    for start, end, label in annot["entities"]:
        j+=1
        # print('j =',j)
        # print(start, end)
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    # print(ents)
    try:
        doc.ents = ents 
    except:
        print(i,j)
        continue
    db.add(doc)

db.to_disk("../10k/tasdsda10.spacy") # save the docbin object
# Out:
# 100%|██████████| 1015/1015 [00:00<00:00, 3117.45it/s]
# Skipping entity
# Skipping entity

# %%
! python -m spacy init config config_gpu.cfg --lang en --pipeline ner --optimize accuracy --force --gpu
# Out:
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: ner
# - Optimize for: accuracy
# - Hardware: GPU
# - Transformer: roberta-base
# ✔ Auto-filled config with all values
# ✔ Saved config
# config_gpu.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config_gpu.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config_gpu.cfg --output ./ --paths.train ./07_1k.spacy --paths.dev ./07_1k.spacy
# Out:
# ^C

# %%
# !python -m spacy evaluate ./model-best36k_last ./0.2_36k.spacy
# !python -m spacy evaluate en_core_web_trf ./annotations2_500.spacy
# Out:
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   99.92
# NER R   99.92
# NER F   99.92
# SPEED   533
#
#
# =============================== NER (per type) ===============================
#
#                P        R        F
# ACT        99.98    99.99    99.98
# ORG        99.85    99.74    99.79
# PERSON     99.74    99.86    99.80
# GPE        99.87   100.00    99.94
# NORP       99.92    99.92    99.92
# DATE      100.00    99.89    99.94
# TIME       99.41    99.41    99.41
# FAC       100.00    99.75    99.88
# GPE_WHO   100.00   100.00   100.00
# LOC       100.00    98.92    99.46
# c:\ProgramData\Anaconda3\lib\site-packages\spacy\util.py:877: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.4 and may not be 100% compatible with the current version (3.5.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
nlp_ner = spacy.load("./model-best")

# %%
doc = nlp_ner('''The global crypto market capitalisation tumbled 3.60 percent over the last 24 hours to $2.18 trillion while the total trading volume fell 6.79 percent to $95.77 billion.

While DeFi ($15.16 billion) accounted for 15.83 percent of the trading volume, stablecoins ($75.16 billion) made up 78.48 percent. The market dominance of Bitcoin rose 0.29 percent to 40.45 percent today morning. Bitcoin is currently trading at $46,560.09.

As for major cryptocurrencies, Bitcoin tumbled 2.46 percent to trade at Rs 37,49,173 while Ethereum fell 4.48 percent at Rs 2,93,527.4. Cardano declined 7.25 percent to Rs 105.4. Avalanche fell 8.77 percent to Rs 8,048, Polkadot tumbled 7.53 percent at Rs 2,137.04 and Litecoin dipped 1.04 percent to Rs 11,725.33 over the last 24 hours. Tether rose 0.12 percent to trade at Rs 80.18.

Memecoin SHIB fell 5.61 percent while Dogecoin decreased 4.29 percent to trade at Rs 13.56. LUNA fell around 6.39 percent to Rs 6,579.55.

Ethereum-based metaverse game The Sandbox co-founder and operations chief Sebastien Borget viewed the metaverse as a digital nation, saying that it’s validating to see his team’s idea for a community-owned, user-customisable online game world embraced by more people.

RELATED STORIES
  2021: A Year Of NFT Craze 
  Elon Musk reveals who he thinks the mysterious Satoshi Nakamoto is 
  Crypto Learn: How to read Crypto Charts? 
“Every day, the map is different. There are new landowners and new communities that come and decide to build things next to each other. I feel like it's a digital nation—living and breathing. That's why it's exciting. It's culturally rich, it’s global, and it's accessible," he continued.

Per blockchain data site Glassnode, there are now 71,364,788 addresses holding some amount of Ethereum, the second-largest cryptocurrency by market capitalisation.

Meanwhile, a white hat hacker won a bug bounty. In early December, the person known as Leon Spacewalker on Twitter had helped Polygon avert a multibillion-dollar disaster. He reported an exploit in a critical Polygon smart contract that held more than nine billion MATIC tokens on Dec. 3, then worth around $20.2 billion. Core developers rushed a fix by Dec. 5. Spacewalker reportedly won a $2.2 million bug bounty, the blockchain network announced yesterday. ''') # input sample text

# %%
ex = 'BREAKING: U.S. Capitol Police are assisting the FBI and the San Francisco Police in a joint investigation into the alleged break-in at the home of House Speaker Pelosi.'
spacy.displacy.render(nlp_ner(ex), style="ent", jupyter=True) # display in Jupyter
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BREAKING
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ACT</span>
# </mark>
# : U.S.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Capitol Police
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     assisting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ACT</span>
# </mark>
#  the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FBI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Police in a joint investigation into the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alleged
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ACT</span>
# </mark>
#  break-in at the home of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Speaker
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pelosi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</div></span>
